# %% [markdown]
# ## Converting Data
#
# - Convert data stored in a `PostgreSQL` database from one data type to another.
# - Explore the expressions needed to convert `text` to `numeric` types and how to format `strings` for `temporal` data.
#
# - **Note:**
#     - 12AM is midnight
#     - 12PM is noon

# %%
cursor.execute("""SELECT table_name FROM information_schema.tables WHERE table_schema = 'public'""")
print('Table in Database:\n')
for table in cursor.fetchall():
       print(table)
# Out:
# Table in Database:
#
# ('film_permit',)
# ('parking_violation',)

# %% [markdown]
# ### Type conversion with a CASE clause
# - One of the `parking_violation` attributes included for each record is the vehicle's location with respect to the street address of the violation.
#     - An `F` value in the `violation_in_front_of_or_opposite` column indicates the vehicle was in front of the recorded address.
#     - A `O` value indicates the vehicle was on the opposite side of the street. The column uses the `TEXT` type to represent the column values.
#     - The same information could be captured using a `BOOLEAN` (true/false) value which uses less memory.
#
# - **Task:** convert `violation_in_front_of_or_opposite` to a `BOOLEAN` column named `is_violation_in_front` using a CASE clause.
#     - `true` for records that occur in front of the recorded address and
#     - `false` for records that occur opposite of the recorded address.

# %%
# %%sql
# SELECT
#     CASE WHEN
#             -- Use true when column value is 'F'
#             violation_in_front_of_or_opposite = 'F' THEN true
#          WHEN
#             -- Use false when column value is 'O'
#             violation_in_front_of_or_opposite = 'O' THEN false
#          ELSE
#             NULL
#     END AS is_violation_in_front
# FROM
#   parking_violation
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [(True,),
#  (True,),
#  (True,),
#  (False,),
#  (True,),
#  (True,),
#  (True,),
#  (True,),
#  (None,),
#  (None,)]

# %% [markdown]
# ### Applying aggregate functions to converted values
# - converting a column's value from TEXT to a number allows for calculations to be performed using aggregation functions.
# - The summons_number is of type TEXT in the `parking_violation dataset`.
# - The maximum (using `MAX(summons_number)`) and minimum (using `MIN(summons_number)`) of the TEXT representation summons_number can be calculated.
# - However, the size of the range (max - min) of summon_number values is not possible to calculated because the operation of subtraction on `TEXT` types is not defined.
#
# >=> converting `summons_number` to a `BIGINT` will resolve this problem.

# %%
# %%sql
# SELECT
#         MAX(summons_number::BIGINT) - MIN(summons_number::BIGINT) AS range_size
# FROM
#       parking_violation;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 1 rows affected.
# [(2954656568,)]

# %% [markdown]
# ### Date parsing and formatting
# #### Cleaning invalid dates
# - The `date_first_observed` column in the `parking_violation` dataset represents the date when the parking violation was first observed by the individual recording the violation.
# - But not all `date_first_observed` values were recorded properly. Some records contain a `0` value for this column which cannot be interpreted as a `DATE` automatically as its meaning in this context is ambiguous. The column values require cleaning to enable conversion to a proper DATE column.
#
#  > => convert the `date_first_observed` value of records with a `0` in `date_first_observed` value into `NULL`

# %%
# %%sql
# SELECT date_first_observed, count(*)
# FROM parking_violation
# GROUP BY date_first_observed
# ORDER BY count DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 33 rows affected.
# [('0', 4919),
#  ('20190707', 7),
#  ('20190625', 6),
#  ('20190702', 6),
#  ('20190621', 6),
#  ('20190701', 4),
#  ('20190614', 4),
#  ('20190628', 3),
#  ('20190706', 3),
#  ('20190630', 3),
#  ('20190627', 3),
#  ('20190626', 3),
#  ('20190704', 3),
#  ('20190622', 2),
#  ('20190711', 2),
#  ('20190612', 2),
#  ('20190712', 2),
#  ('20190705', 2),
#  ('20190417', 2),
#  ('20190613', 2),
#  ('20190624', 2),
#  ('20190605', 2),
#  ('20190629', 2),
#  ('20190517', 1),
#  ('20190708', 1),
#  ('20190714', 1),
#  ('20190615', 1),
#  ('20190525', 1),
#  ('20190703', 1),
#  ('20190523', 1),
#  ('20190623', 1),
#  ('20190619', 1),
#  ('20190618', 1)]

# %%
# %%sql
# With sub AS (SELECT
#    DATE(NULLIF(date_first_observed, '0')) AS date_first_observed
# FROM
#    parking_violation)
#
# SELECT date_first_observed, COUNT(*) AS count
# FROM sub
# GROUP BY date_first_observed
# ORDER BY count DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 33 rows affected.
# [(None, 4919),
#  (datetime.date(2019, 7, 7), 7),
#  (datetime.date(2019, 7, 2), 6),
#  (datetime.date(2019, 6, 25), 6),
#  (datetime.date(2019, 6, 21), 6),
#  (datetime.date(2019, 6, 14), 4),
#  (datetime.date(2019, 7, 1), 4),
#  (datetime.date(2019, 6, 26), 3),
#  (datetime.date(2019, 6, 30), 3),
#  (datetime.date(2019, 6, 28), 3),
#  (datetime.date(2019, 7, 6), 3),
#  (datetime.date(2019, 6, 27), 3),
#  (datetime.date(2019, 7, 4), 3),
#  (datetime.date(2019, 7, 11), 2),
#  (datetime.date(2019, 6, 29), 2),
#  (datetime.date(2019, 6, 13), 2),
#  (datetime.date(2019, 6, 12), 2),
#  (datetime.date(2019, 6, 24), 2),
#  (datetime.date(2019, 6, 22), 2),
#  (datetime.date(2019, 7, 12), 2),
#  (datetime.date(2019, 7, 5), 2),
#  (datetime.date(2019, 4, 17), 2),
#  (datetime.date(2019, 6, 5), 2),
#  (datetime.date(2019, 7, 8), 1),
#  (datetime.date(2019, 6, 23), 1),
#  (datetime.date(2019, 6, 18), 1),
#  (datetime.date(2019, 6, 15), 1),
#  (datetime.date(2019, 5, 25), 1),
#  (datetime.date(2019, 7, 14), 1),
#  (datetime.date(2019, 7, 3), 1),
#  (datetime.date(2019, 5, 17), 1),
#  (datetime.date(2019, 6, 19), 1),
#  (datetime.date(2019, 5, 23), 1)]

# %%
# %%sql
# SELECT
#     summons_number,
#     DATE(issue_date) AS issue_date,
#     DATE(NULLIF(date_first_observed,'0')) AS date_first_observed
# FROM
#   parking_violation
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('1447152396', datetime.date(2019, 6, 28), None),
#  ('1447152554', datetime.date(2019, 6, 16), None),
#  ('1447295250', datetime.date(2019, 6, 30), None),
#  ('1447153340', datetime.date(2019, 6, 28), None),
#  ('1447153352', datetime.date(2019, 7, 6), None),
#  ('1447153790', datetime.date(2019, 6, 16), None),
#  ('1447153819', datetime.date(2019, 6, 15), None),
#  ('1447153820', datetime.date(2019, 6, 23), None),
#  ('1447153844', datetime.date(2019, 6, 30), None),
#  ('1413267488', datetime.date(2019, 4, 30), None)]

# %%
# %%sql
# SELECT
#   summons_number,
#     TO_CHAR(issue_date, 'YYYYMMDD') AS issue_date,
#     TO_CHAR(date_first_observed, 'YYYYMMDD') AS date_first_observed
# FROM (
#   SELECT
#     summons_number,
#     DATE(issue_date) AS issue_date,
#     DATE(NULLIF(date_first_observed,'0')) AS date_first_observed
#   FROM
#     parking_violation
# ) sub
#
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('1447152396', '20190628', None),
#  ('1447152554', '20190616', None),
#  ('1447295250', '20190630', None),
#  ('1447153340', '20190628', None),
#  ('1447153352', '20190706', None),
#  ('1447153790', '20190616', None),
#  ('1447153819', '20190615', None),
#  ('1447153820', '20190623', None),
#  ('1447153844', '20190630', None),
#  ('1413267488', '20190430', None)]

# %% [markdown]
# ### Timestamp parsing and formatting

# %%
# %%sql
# SELECT
#     summons_number, violation_time,
#     --CONCAT(12,substr(violation_time,3,2),'P') AS violation_time1
#     CONCAT(12,substr(violation_time,3,2),'P') AS violation_time2
#
# FROM parking_violation
# WHERE --violation_time NOT SIMILAR TO '00%P'  AND
#      --violation_time SIMILAR TO '00%A' AND
#      violation_time SIMILAR TO '2%'
# ORDER BY summons_number
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 0 rows affected.
# []

# %%
# %%sql
#  WITH sub AS (SELECT
#     summons_number, violation_time,
#     CONCAT(12,substr(violation_time,3,2),'P') AS violation_time1,
#     CONCAT(12,substr(violation_time,3,2),'P') AS violation_time2
# FROM parking_violation
# WHERE --violation_time NOT SIMILAR TO '00%P'  AND
#       violation_time SIMILAR TO '00%A'
#       --violation_time SIMILAR TO '2%'
#              )
#
# --UPDATE parking_violation pv
# --SET
# --    violation_time = violation_time1
# --    --violation_time = violation_time2
# --FROM sub
# --
# --WHERE pv.summons_number = sub.summons_number;
#
# SELECT summons_number, violation_time
# FROM parking_violation
# WHERE summons_number LIKE '1309081189'
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 1 rows affected.
# [('1309081189', '1250PM')]

# %%
# %%sql
# SELECT
#     violation_time,
#     violation_time1
# FROM
#         (SELECT
#             summons_number, violation_time,
#             CONCAT(violation_time,'M') AS violation_time1
#         FROM parking_violation
#         WHERE violation_time SIMILAR TO '%[A-Z]'
#
#         )sub
#
#  WHERE violation_time1 SIMILAR TO '00%'
#     OR violation_time SIMILAR TO '1[3-9]%'
#     OR violation_time SIMILAR TO '2[0-4]%';
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 0 rows affected.
# []

# %%
# %%sql
# SELECT
#     violation_time,
#     TO_TIMESTAMP(violation_time1, 'HH12MIPM')::TIME AS violation_time1
# FROM   (SELECT
#             summons_number,
#             violation_time,
#             CONCAT(violation_time,'M') AS violation_time1
#         FROM
#             (SELECT
#                 summons_number,
#                 CASE
#                     WHEN violation_time ='0059P' THEN '1259P'
#                     WHEN violation_time ='1955P' THEN '0755P'
#                     WHEN violation_time ='1634P' THEN '0434P'
#                     ELSE violation_time END AS violation_time
#             FROM
#                parking_violation)sub1
#         WHERE violation_time SIMILAR TO '%[A-Z]'
#               AND violation_time IS NOT NULL) sub2
# WHERE violation_time1 IS NOT NULL
# LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 20 rows affected.
# [('1000AM', datetime.time(10, 0)),
#  ('0107AM', datetime.time(1, 7)),
#  ('0410AM', datetime.time(4, 10)),
#  ('0935AM', datetime.time(9, 35)),
#  ('1217PM', datetime.time(12, 17)),
#  ('0124AM', datetime.time(1, 24)),
#  ('0500AM', datetime.time(5, 0)),
#  ('1221AM', datetime.time(0, 21)),
#  ('1241AM', datetime.time(0, 41)),
#  ('1110AM', datetime.time(11, 10)),
#  ('0105AM', datetime.time(1, 5)),
#  ('1000PM', datetime.time(22, 0)),
#  ('0843AM', datetime.time(8, 43)),
#  ('0955PM', datetime.time(21, 55)),
#  ('0508PM', datetime.time(17, 8)),
#  ('1100AM', datetime.time(11, 0)),
#  ('1100AM', datetime.time(11, 0)),
#  ('1100AM', datetime.time(11, 0)),
#  ('0718AM', datetime.time(7, 18)),
#  ('0722AM', datetime.time(7, 22))]

# %%
# %%sql
#
# WITH sub AS (
#
# SELECT
#             summons_number,
#             violation_time,
#         CONCAT(violation_time,'M') AS violation_time1
#         FROM
#             (SELECT
#                 summons_number,
#                 CASE
#                     WHEN violation_time ='0059P' THEN '1259P'
#                     WHEN violation_time ='1955P' THEN '0755P'
#                     WHEN violation_time ='1634P' THEN '0434P'
#                     ELSE violation_time END AS violation_time
#             FROM
#                parking_violation)sub1
#         WHERE violation_time SIMILAR TO '%[A-Z]'
#               AND violation_time IS NOT NULL
# )
#
# --UPDATE parking_violation pv
# --
# --SET violation_time =violation_time1
# --FROM sub
# --WHERE pv.summons_number=sub.summons_number;
# --
# SELECT violation_time FROM parking_violation LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('1000AM',),
#  ('0107AM',),
#  ('0410AM',),
#  ('0935AM',),
#  ('1217PM',),
#  ('0124AM',),
#  ('0500AM',),
#  ('1221AM',),
#  ('1241AM',),
#  ('0108',)]

# %%
# %%sql
# SELECT violation_time FROM parking_violation
# WHERE NOT violation_time LIKE '%M'
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 3 rows affected.
# [('0108',), ('0855',), ('1011',)]

# %%
# %%sql
# SELECT
#   -- Populate column with violation_time hours
#   EXTRACT('hour' FROM violation_time) AS hour,
#   COUNT(*)
# FROM (
#     SELECT
#       TO_TIMESTAMP(violation_time1, 'HH12MIPM')::TIME as violation_time
#     FROM
#       (SELECT
#             summons_number,
#             violation_time,
#             CONCAT(violation_time,'M') AS violation_time1
#         FROM
#             (SELECT
#                 summons_number,
#                 CASE
#                     WHEN violation_time ='0059P' THEN '1259P'
#                     WHEN violation_time ='1955P' THEN '0755P'
#                     WHEN violation_time ='1634P' THEN '0434P'
#                     ELSE violation_time END AS violation_time
#             FROM
#                parking_violation)sub1
#         WHERE violation_time SIMILAR TO '%[A-Z]'
#               AND violation_time IS NOT NULL) sub2
#     WHERE
#       violation_time IS NOT NULL
# ) sub
# GROUP BY
#   hour
# ORDER BY
#   hour
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 24 rows affected.
# [(0.0, 136),
#  (1.0, 242),
#  (2.0, 214),
#  (3.0, 149),
#  (4.0, 150),
#  (5.0, 122),
#  (6.0, 107),
#  (7.0, 145),
#  (8.0, 270),
#  (9.0, 319),
#  (10.0, 266),
#  (11.0, 329),
#  (12.0, 280),
#  (13.0, 204),
#  (14.0, 221),
#  (15.0, 172),
#  (16.0, 218),
#  (17.0, 296),
#  (18.0, 201),
#  (19.0, 182),
#  (20.0, 214),
#  (21.0, 194),
#  (22.0, 234),
#  (23.0, 126)]

# %% [markdown]
# ### A parking violation report by day of the month
# - parking tickets are more likely to be given out at the end of the month compared to during the month,
# - preparing data to get a sense of the distribution of tickets by day of the month.
#     - convert the strings representing the `issue_date` into proper PostgreSQL DATE values.
#     - extract the day of the month required to produce the distribution of violations by month day.

# %%
# %%sql
# SELECT
#   -- Convert issue_date to a DATE value
#   issue_date::DATE AS issue_date
# FROM
#   parking_violation
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [(datetime.date(2019, 6, 28),),
#  (datetime.date(2019, 6, 16),),
#  (datetime.date(2019, 6, 30),),
#  (datetime.date(2019, 6, 28),),
#  (datetime.date(2019, 7, 6),),
#  (datetime.date(2019, 6, 16),),
#  (datetime.date(2019, 6, 15),),
#  (datetime.date(2019, 6, 23),),
#  (datetime.date(2019, 6, 30),),
#  (datetime.date(2019, 4, 30),)]

# %%
# %%sql
#
# SELECT
#   -- Create issue_day from the day value of issue_date
#   EXTRACT(DAY FROM issue_date) AS issue_day,
#   -- Include the count of violations for each day
#   COUNT(*)
# FROM (
#   SELECT
#     -- Convert issue_date to a `DATE` value
#     DATE(issue_date) AS issue_date
#   FROM
#     parking_violation
# ) sub
# GROUP BY
#   issue_day
# ORDER BY
#   issue_day;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 31 rows affected.
# [(1.0, 153),
#  (2.0, 161),
#  (3.0, 154),
#  (4.0, 198),
#  (5.0, 205),
#  (6.0, 171),
#  (7.0, 148),
#  (8.0, 123),
#  (9.0, 120),
#  (10.0, 86),
#  (11.0, 118),
#  (12.0, 128),
#  (13.0, 147),
#  (14.0, 201),
#  (15.0, 151),
#  (16.0, 144),
#  (17.0, 167),
#  (18.0, 155),
#  (19.0, 181),
#  (20.0, 171),
#  (21.0, 151),
#  (22.0, 132),
#  (23.0, 154),
#  (24.0, 169),
#  (25.0, 177),
#  (26.0, 213),
#  (27.0, 297),
#  (28.0, 204),
#  (29.0, 151),
#  (30.0, 263),
#  (31.0, 7)]

# %% [markdown]
# ### Risky parking behavior
# - The `parking_violation` table contains many parking violation details. However, it's unclear what causes an individual to violate parking restrictions. One hypothesis is that violators attempt to park in restricted areas just before the parking restrictions end.
#
# - convert violation_time, and `to_hours_in_effect` to `TIMESTAMP` values for violations that took place in locations with partial day restrictions,
# - calculate the interval between the `violation_time` and `to_hours_in_effect` for these records, and
# - identify the records where the `violation_time` is less than 1 hour before `to_hours_in_effect`.

# %%
# %%sql
# SELECT to_hours_in_effect, COUNT(*)
#         FROM
#             (SELECT
#                 summons_number,
#                 CASE
#                     WHEN to_hours_in_effect ='0000' THEN '1200A'
#                     WHEN to_hours_in_effect ='ALL' THEN '1159P'
#                     WHEN to_hours_in_effect ='1600P' THEN '0400P'
#                     WHEN to_hours_in_effect ='1800P' THEN '0600P'
#                     WHEN to_hours_in_effect ='2000P' THEN '0800P'
#                     --WHEN length(to_hours_in_effect) != 6 THEN NULL
#                     ELSE to_hours_in_effect END AS to_hours_in_effect
#             FROM
#                parking_violation)sub1
# GROUP BY to_hours_in_effect
# ORDER BY to_hours_in_effect
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 34 rows affected.
# [('0100PM', 41),
#  ('0130PM', 8),
#  ('0200PM', 29),
#  ('0300AM', 14),
#  ('0300PM', 1),
#  ('0400AM', 3),
#  ('0400PM', 23),
#  ('0500AM', 8),
#  ('0500PM', 12),
#  ('0600AM', 57),
#  ('0600PM', 37),
#  ('0630AM', 1),
#  ('0700AM', 18),
#  ('0700PM', 120),
#  ('0800AM', 35),
#  ('0800PM', 6),
#  ('0830AM', 25),
#  ('0900AM', 19),
#  ('0930AM', 15),
#  ('1000AM', 38),
#  ('1000PM', 2),
#  ('1030AM', 55),
#  ('1100AM', 20),
#  ('1100PM', 5),
#  ('1130AM', 14),
#  ('1159AM', 1),
#  ('1159PM', 4325),
#  ('1200AM', 1),
#  ('1200PM', 4),
#  ('1230AM', 6),
#  ('1230PM', 48),
#  ('1600PM', 3),
#  ('1800PM', 2),
#  ('2000PM', 4)]

# %%
# %%sql
# SELECT DISTINCT to_hours_in_effect
# FROM parking_violation
# WHERE  to_hours_in_effect SIMILAR TO '00%'
#     OR to_hours_in_effect SIMILAR TO '1[3-9]%'
#     OR to_hours_in_effect SIMILAR TO '2[0-4]%';
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 3 rows affected.
# [('1600PM',), ('1800PM',), ('2000PM',)]

# %%
# %%sql
# WITH SUB AS (SELECT
#             summons_number,
#             to_hours_in_effect,
#              CASE WHEN to_hours_in_effect SIMILAR TO '%[A_Z]'
#                     AND to_hours_in_effect NOT SIMILAR TO '%M' THEN CONCAT(to_hours_in_effect,'M')
#                   ELSE to_hours_in_effect
#              END AS to_hours_in_effect1
#         FROM
#             (SELECT
#                 summons_number,
#                 CASE
#                     WHEN to_hours_in_effect ='0000' THEN '1159P'
#                     WHEN to_hours_in_effect ='ALL' THEN '1159P'
#                     WHEN to_hours_in_effect ='1600P' THEN '0400P'
#                     WHEN to_hours_in_effect ='1800P' THEN '0600P'
#                     WHEN to_hours_in_effect ='2000P' THEN '0800P'
#                     --WHEN length(to_hours_in_effect) != 5 THEN NULL
#                     ELSE to_hours_in_effect END AS to_hours_in_effect
#             FROM
#                parking_violation)sub1
#         WHERE  to_hours_in_effect IS NOT NULL)
#
# UPDATE parking_violation pv
#
# SET to_hours_in_effect=to_hours_in_effect1
# FROM SUB
# WHERE pv.summons_number=SUB.summons_number;
#
# SELECT to_hours_in_effect, COUNT(*) FROM parking_violation
# GROUP BY to_hours_in_effect
# ORDER BY to_hours_in_effect
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 5000 rows affected.
# 30 rows affected.
# [('0100PM', 41),
#  ('0130PM', 8),
#  ('0200PM', 29),
#  ('0300AM', 14),
#  ('0300PM', 1),
#  ('0400AM', 3),
#  ('0400PM', 26),
#  ('0500AM', 8),
#  ('0500PM', 12),
#  ('0600AM', 57),
#  ('0600PM', 39),
#  ('0630AM', 1),
#  ('0700AM', 18),
#  ('0700PM', 120),
#  ('0800AM', 35),
#  ('0800PM', 10),
#  ('0830AM', 25),
#  ('0900AM', 19),
#  ('0930AM', 15),
#  ('1000AM', 38),
#  ('1000PM', 2),
#  ('1030AM', 55),
#  ('1100AM', 20),
#  ('1100PM', 5),
#  ('1130AM', 14),
#  ('1159AM', 1),
#  ('1159PM', 4326),
#  ('1200PM', 4),
#  ('1230AM', 6),
#  ('1230PM', 48)]

# %%
# %%sql
# SELECT DISTINCT from_hours_in_effect
# FROM parking_violation
# WHERE  from_hours_in_effect SIMILAR TO '00%'
#     OR from_hours_in_effect SIMILAR TO '1[3-9]%'
#     OR from_hours_in_effect SIMILAR TO '2[0-4]%'
#     OR from_hours_in_effect NOT SIMILAR TO '0%';
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 15 rows affected.
# [('ALL',),
#  ('1159P',),
#  ('0000',),
#  ('1200A',),
#  ('1136A',),
#  ('1030A',),
#  ('1130',),
#  ('1100P',),
#  ('1100A',),
#  ('1130A',),
#  ('1000A',),
#  ('1201A',),
#  ('1200P',),
#  ('1130P',),
#  ('1000P',)]

# %%
# %%sql
# SELECT
#                 summons_number,
#                 from_hours_in_effect
#             FROM
#                parking_violation
#             WHERE length(from_hours_in_effect) != 6
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 5 rows affected.
# [('1422683254', '0800'),
#  ('1454070122', '0800'),
#  ('1454093195', '1130'),
#  ('1454169126', '0700'),
#  ('1452145076', '0800')]

# %%
# %%sql
# WITH SUB AS (SELECT
#             summons_number,
#             from_hours_in_effect,
#              CASE WHEN from_hours_in_effect SIMILAR TO '%[A_P]' AND
#                        from_hours_in_effect NOT SIMILAR TO '%M' THEN CONCAT(from_hours_in_effect,'M')
#                   ELSE from_hours_in_effect
#              END AS from_hours_in_effect1
#         FROM
#             (SELECT
#                 summons_number,
#                 CASE
#                     WHEN from_hours_in_effect ='0000' THEN '1200AM'
#                     WHEN from_hours_in_effect ='ALL' THEN '1200AM'
#                     WHEN length(from_hours_in_effect) != 6 THEN NULL
#                     ELSE from_hours_in_effect END AS from_hours_in_effect
#             FROM
#                parking_violation)sub1
#         --WHERE  from_hours_in_effect IS NOT NULL
#             )
#
# UPDATE parking_violation pv
#
# SET from_hours_in_effect=from_hours_in_effect1
# FROM SUB
# WHERE pv.summons_number=SUB.summons_number;
#
# SELECT from_hours_in_effect, COUNT(*) FROM parking_violation
# GROUP BY from_hours_in_effect
# ORDER BY from_hours_in_effect
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 5000 rows affected.
# 28 rows affected.
# [('0100AM', 30),
#  ('0200PM', 3),
#  ('0300AM', 11),
#  ('0400PM', 5),
#  ('0500PM', 1),
#  ('0600AM', 7),
#  ('0700AM', 152),
#  ('0700PM', 1),
#  ('0730AM', 36),
#  ('0800AM', 68),
#  ('0800PM', 4),
#  ('0830AM', 49),
#  ('0900AM', 56),
#  ('0900PM', 22),
#  ('0930AM', 16),
#  ('1000AM', 14),
#  ('1000PM', 17),
#  ('1030AM', 1),
#  ('1100AM', 84),
#  ('1100PM', 6),
#  ('1130AM', 38),
#  ('1130PM', 1),
#  ('1136AM', 1),
#  ('1159PM', 1),
#  ('1200AM', 4347),
#  ('1200PM', 8),
#  ('1201AM', 1),
#  (None, 20)]

# %%
# %%sql
#
#
# SELECT
#     TO_TIMESTAMP(from_hours_in_effect, 'HH12MIPM')::time as from_hours_in_effect,
#     TO_TIMESTAMP(to_hours_in_effect, 'HH12MIPM')::time as to_hours_in_effect,
#     TO_TIMESTAMP(violation_time, 'HH12MIPM')::time as violation_time,
#     COUNT(*)
# FROM parking_violation
# WHERE NOT (from_hours_in_effect = '1200AM' AND to_hours_in_effect ='1159PM')
# GROUP BY from_hours_in_effect,to_hours_in_effect,violation_time
#
# ORDER BY from_hours_in_effect,to_hours_in_effect,violation_time, COUNT(*)
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [(datetime.time(0, 0), datetime.time(3, 0), datetime.time(0, 35), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(0, 46), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(0, 58), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 0), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 2), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 3), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 7), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 16), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 17), 1),
#  (datetime.time(0, 0), datetime.time(3, 0), datetime.time(1, 20), 1)]

# %%
# %%sql
# SELECT
#           summons_number,
#           from_hours_in_effect,
#           violation_time,
#           to_hours_in_effect,
#
#           CASE WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#
#                 WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  THEN  EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#                 ELSE 0
#                 END AS hours,
#
#          CASE WHEN to_hours_in_effect >= violation_time THEN
#                     EXTRACT('minute' FROM to_hours_in_effect - violation_time)
#                ELSE EXTRACT('minute' FROM to_hours_in_effect - violation_time) + 60
#                END AS minutes
#     FROM (
#           SELECT
#             summons_number,
#                 TO_TIMESTAMP(from_hours_in_effect, 'HH12MIPM')::time as from_hours_in_effect,
#                 TO_TIMESTAMP(to_hours_in_effect, 'HH12MIPM')::time as to_hours_in_effect,
#                 TO_TIMESTAMP(violation_time, 'HH12MIPM')::time as violation_time
#           FROM
#             parking_violation
#           WHERE
#             NOT (from_hours_in_effect = '1200AM' AND to_hours_in_effect = '1159PM') )sub
#
# WHERE violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#         AND to_hours_in_effect > from_hours_in_effect
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('1439394799', datetime.time(7, 0), datetime.time(6, 40), datetime.time(19, 0), 0.0, 20.0),
#  ('1446646427', datetime.time(0, 0), datetime.time(21, 35), datetime.time(12, 0), 0.0, 25.0),
#  ('1454093201', datetime.time(11, 30), datetime.time(0, 10), datetime.time(13, 0), 0.0, 50.0),
#  ('1454170517', datetime.time(7, 0), datetime.time(6, 46), datetime.time(19, 0), 0.0, 14.0),
#  ('1451849291', datetime.time(0, 1), datetime.time(12, 43), datetime.time(12, 0), 0.0, 17.0),
#  ('1452145155', datetime.time(8, 30), datetime.time(8, 20), datetime.time(9, 0), 0.0, 40.0),
#  ('1452145600', datetime.time(11, 30), datetime.time(0, 7), datetime.time(13, 0), 0.0, 53.0),
#  ('1452145611', datetime.time(11, 30), datetime.time(0, 40), datetime.time(13, 0), 0.0, 20.0),
#  ('1452145623', datetime.time(11, 30), datetime.time(0, 45), datetime.time(13, 0), 0.0, 15.0),
#  ('1413267488', datetime.time(7, 0), datetime.time(1, 8), datetime.time(19, 0), 0.0, 52.0)]

# %%
# %%sql
# SELECT
#         summons_number,
#         from_hours_in_effect,
#         violation_time,
#         to_hours_in_effect,
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '05:00:00'::time
#                     THEN  24- EXTRACT('hour' FROM to_hours_in_effect) + EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                     THEN (- EXTRACT('hour' FROM violation_time ) + EXTRACT('hour' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (24- EXTRACT('hour' FROM violation_time )+EXTRACT('hour' FROM to_hours_in_effect) )
#             ELSE EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             END AS hours,
#
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '06:00:00'::time
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) + EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                    THEN (- EXTRACT('minute' FROM violation_time ) + EXTRACT('minute' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (-EXTRACT('minute' FROM violation_time )+EXTRACT('minute' FROM to_hours_in_effect) )
#             ELSE EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             END AS minutes
#     FROM
#         (SELECT
#             summons_number,
#                 TO_TIMESTAMP(from_hours_in_effect, 'HH12MIPM')::time as from_hours_in_effect,
#                 TO_TIMESTAMP(to_hours_in_effect, 'HH12MIPM')::time as to_hours_in_effect,
#                 TO_TIMESTAMP(violation_time, 'HH12MIPM')::time as violation_time
#           FROM
#             parking_violation
#           WHERE NOT (from_hours_in_effect = '1200AM' AND to_hours_in_effect = '1159PM')
#         ) sub
#
#
# LIMIT 15;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 15 rows affected.
# [('1447634159', datetime.time(20, 0), datetime.time(22, 22), datetime.time(5, 0), 7.0, -22.0),
#  ('1447672290', datetime.time(22, 0), datetime.time(3, 50), datetime.time(7, 0), 4.0, -50.0),
#  ('1447680091', datetime.time(22, 0), datetime.time(4, 40), datetime.time(7, 0), 3.0, -40.0),
#  ('1447680133', datetime.time(22, 0), datetime.time(4, 12), datetime.time(7, 0), 3.0, -12.0),
#  ('1447680194', datetime.time(22, 0), datetime.time(4, 30), datetime.time(7, 0), 3.0, -30.0),
#  ('1422683254', None, datetime.time(8, 30), datetime.time(10, 30), 2.0, 0.0),
#  ('1434758126', datetime.time(7, 0), datetime.time(8, 33), datetime.time(19, 0), 10.0, 27.0),
#  ('4011361938', None, datetime.time(20, 34), datetime.time(10, 30), -10.0, -4.0),
#  ('4011361975', None, datetime.time(20, 48), datetime.time(10, 30), -10.0, -18.0),
#  ('4011362750', None, datetime.time(10, 20), datetime.time(10, 30), 0.0, 10.0),
#  ('1448519317', datetime.time(7, 0), datetime.time(7, 19), datetime.time(19, 0), 11.0, 41.0),
#  ('4011362815', None, datetime.time(10, 52), datetime.time(10, 30), 0.0, -22.0),
#  ('4011362827', None, datetime.time(11, 5), datetime.time(10, 30), 0.0, -35.0),
#  ('4011362839', None, datetime.time(11, 8), datetime.time(10, 30), 0.0, -38.0),
#  ('1449252564', datetime.time(7, 0), datetime.time(12, 47), datetime.time(16, 0), 3.0, 13.0)]

# %% [markdown]
# ###  The records where the violation_time is less than 1 hour before `to_hours_in_effect`.

# %%
# %%sql
#
# With diff_time AS (
# SELECT
#         summons_number,
#         from_hours_in_effect,
#         violation_time,
#         to_hours_in_effect,
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '05:00:00'::time
#                     THEN  24- EXTRACT('hour' FROM to_hours_in_effect) + EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                     THEN (- EXTRACT('hour' FROM violation_time ) + EXTRACT('hour' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (24- EXTRACT('hour' FROM violation_time )+EXTRACT('hour' FROM to_hours_in_effect) )
#             ELSE EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             END AS hours,
#
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '06:00:00'::time
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) + EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                    THEN (- EXTRACT('minute' FROM violation_time ) + EXTRACT('minute' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (-EXTRACT('minute' FROM violation_time )+EXTRACT('minute' FROM to_hours_in_effect) )
#             ELSE EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             END AS minutes
#     FROM
#         (SELECT
#             summons_number,
#                 TO_TIMESTAMP(from_hours_in_effect, 'HH12MIPM')::time as from_hours_in_effect,
#                 TO_TIMESTAMP(to_hours_in_effect, 'HH12MIPM')::time as to_hours_in_effect,
#                 TO_TIMESTAMP(violation_time, 'HH12MIPM')::time as violation_time
#           FROM
#             parking_violation
#           WHERE NOT (from_hours_in_effect = '1200AM' AND to_hours_in_effect = '1159PM')
#         ) sub
# )
#
# SELECT count(hours) AS violation_before_to_hours
# FROM diff_time
# WHERE
#     hours*60 + minutes >  0
# AND
#     hours*60 + minutes < 60
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 1 rows affected.
# [(201,)]

# %%
# %%sql
#
# With diff_time AS (
# SELECT
#         summons_number,
#         from_hours_in_effect,
#         violation_time,
#         to_hours_in_effect,
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '05:00:00'::time
#                     THEN  24- EXTRACT('hour' FROM to_hours_in_effect) + EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                     THEN (- EXTRACT('hour' FROM violation_time ) + EXTRACT('hour' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (24- EXTRACT('hour' FROM violation_time )+EXTRACT('hour' FROM to_hours_in_effect) )
#             ELSE EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             END AS hours,
#
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '06:00:00'::time
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) + EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                    THEN (- EXTRACT('minute' FROM violation_time ) + EXTRACT('minute' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (-EXTRACT('minute' FROM violation_time )+EXTRACT('minute' FROM to_hours_in_effect) )
#             ELSE EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             END AS minutes
#     FROM
#         (SELECT
#             summons_number,
#                 TO_TIMESTAMP(from_hours_in_effect, 'HH12MIPM')::time as from_hours_in_effect,
#                 TO_TIMESTAMP(to_hours_in_effect, 'HH12MIPM')::time as to_hours_in_effect,
#                 TO_TIMESTAMP(violation_time, 'HH12MIPM')::time as violation_time
#           FROM
#             parking_violation
#           WHERE NOT (from_hours_in_effect = '1200AM' AND to_hours_in_effect = '1159PM')
#         ) sub
# )
#
# SELECT summons_number, from_hours_in_effect, violation_time, to_hours_in_effect, hours, minutes
# FROM diff_time
# WHERE hours * 60 +minutes <60
# AND hours * 60 +minutes >0
# ORDER BY hours, minutes
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 201 rows affected.
# [('1452145880', datetime.time(7, 30), datetime.time(7, 58), datetime.time(8, 0), 0.0, 2.0),
#  ('1452145714', datetime.time(7, 30), datetime.time(7, 58), datetime.time(8, 0), 0.0, 2.0),
#  ('1447832279', datetime.time(9, 0), datetime.time(10, 55), datetime.time(11, 0), 0.0, 5.0),
#  ('1454078777', datetime.time(7, 30), datetime.time(7, 55), datetime.time(8, 0), 0.0, 5.0),
#  ('1437647479', datetime.time(11, 30), datetime.time(12, 55), datetime.time(13, 0), 0.0, 5.0),
#  ('1452146070', datetime.time(7, 30), datetime.time(7, 55), datetime.time(8, 0), 0.0, 5.0),
#  ('1451597010', datetime.time(7, 30), datetime.time(7, 55), datetime.time(8, 0), 0.0, 5.0),
#  ('1452145660', datetime.time(8, 30), datetime.time(8, 55), datetime.time(9, 0), 0.0, 5.0),
#  ('1452145702', datetime.time(7, 30), datetime.time(7, 55), datetime.time(8, 0), 0.0, 5.0),
#  ('1454090364', datetime.time(8, 30), datetime.time(8, 54), datetime.time(9, 0), 0.0, 6.0),
#  ('1452145106', datetime.time(8, 0), datetime.time(8, 24), datetime.time(8, 30), 0.0, 6.0),
#  ('1452144977', datetime.time(7, 30), datetime.time(7, 53), datetime.time(8, 0), 0.0, 7.0),
#  ('1452145647', datetime.time(11, 30), datetime.time(12, 52), datetime.time(13, 0), 0.0, 8.0),
#  ('1452145933', datetime.time(8, 0), datetime.time(8, 22), datetime.time(8, 30), 0.0, 8.0),
#  ('1452144278', datetime.time(8, 0), datetime.time(8, 21), datetime.time(8, 30), 0.0, 9.0),
#  ('1451596960', datetime.time(7, 30), datetime.time(7, 51), datetime.time(8, 0), 0.0, 9.0),
#  ('1452017001', datetime.time(8, 0), datetime.time(8, 21), datetime.time(8, 30), 0.0, 9.0),
#  ('1452146056', datetime.time(8, 0), datetime.time(8, 20), datetime.time(8, 30), 0.0, 10.0),
#  ('1449413249', datetime.time(8, 30), datetime.time(9, 50), datetime.time(10, 0), 0.0, 10.0),
#  ('1452145866', datetime.time(7, 30), datetime.time(7, 50), datetime.time(8, 0), 0.0, 10.0),
#  ('1438238940', datetime.time(7, 30), datetime.time(7, 50), datetime.time(8, 0), 0.0, 10.0),
#  ('1442671695', datetime.time(7, 30), datetime.time(7, 50), datetime.time(8, 0), 0.0, 10.0),
#  ('1449219342', datetime.time(8, 0), datetime.time(9, 20), datetime.time(9, 30), 0.0, 10.0),
#  ('4011362750', None, datetime.time(10, 20), datetime.time(10, 30), 0.0, 10.0),
#  ('1454078753', datetime.time(7, 30), datetime.time(7, 50), datetime.time(8, 0), 0.0, 10.0),
#  ('1452032555', datetime.time(9, 0), datetime.time(9, 20), datetime.time(9, 30), 0.0, 10.0),
#  ('1452020061', datetime.time(8, 30), datetime.time(8, 50), datetime.time(9, 0), 0.0, 10.0),
#  ('1451601141', datetime.time(8, 30), datetime.time(8, 50), datetime.time(9, 0), 0.0, 10.0),
#  ('1451597009', datetime.time(7, 30), datetime.time(7, 50), datetime.time(8, 0), 0.0, 10.0),
#  ('1452145696', datetime.time(7, 30), datetime.time(7, 49), datetime.time(8, 0), 0.0, 11.0),
#  ('1454090352', datetime.time(8, 30), datetime.time(8, 49), datetime.time(9, 0), 0.0, 11.0),
#  ('1452145090', datetime.time(8, 0), datetime.time(8, 19), datetime.time(8, 30), 0.0, 11.0),
#  ('1452146068', datetime.time(7, 30), datetime.time(7, 49), datetime.time(8, 0), 0.0, 11.0),
#  ('1443132287', datetime.time(11, 30), datetime.time(12, 48), datetime.time(13, 0), 0.0, 12.0),
#  ('1439560584', datetime.time(8, 0), datetime.time(17, 48), datetime.time(18, 0), 0.0, 12.0),
#  ('1454078741', datetime.time(7, 30), datetime.time(7, 48), datetime.time(8, 0), 0.0, 12.0),
#  ('1452144461', datetime.time(8, 30), datetime.time(8, 48), datetime.time(9, 0), 0.0, 12.0),
#  ('1451596996', datetime.time(7, 30), datetime.time(7, 47), datetime.time(8, 0), 0.0, 13.0),
#  ('1451596959', datetime.time(7, 30), datetime.time(7, 47), datetime.time(8, 0), 0.0, 13.0),
#  ('1452016940', datetime.time(8, 30), datetime.time(8, 45), datetime.time(9, 0), 0.0, 15.0),
#  ('1452145829', datetime.time(9, 0), datetime.time(10, 15), datetime.time(10, 30), 0.0, 15.0),
#  ('1452019988', datetime.time(7, 30), datetime.time(7, 45), datetime.time(8, 0), 0.0, 15.0),
#  ('1452145568', datetime.time(8, 0), datetime.time(9, 15), datetime.time(9, 30), 0.0, 15.0),
#  ('1449413237', datetime.time(8, 30), datetime.time(9, 45), datetime.time(10, 0), 0.0, 15.0),
#  ('1452145945', datetime.time(8, 30), datetime.time(8, 45), datetime.time(9, 0), 0.0, 15.0),
#  ('1438225740', datetime.time(9, 30), datetime.time(10, 45), datetime.time(11, 0), 0.0, 15.0),
#  ('1452144989', datetime.time(8, 0), datetime.time(8, 14), datetime.time(8, 30), 0.0, 16.0),
#  ('1451395735', datetime.time(7, 0), datetime.time(15, 44), datetime.time(16, 0), 0.0, 16.0),
#  ('1451596984', datetime.time(7, 30), datetime.time(7, 44), datetime.time(8, 0), 0.0, 16.0),
#  ('1452145775', datetime.time(8, 0), datetime.time(8, 14), datetime.time(8, 30), 0.0, 16.0),
#  ('1442671725', datetime.time(8, 0), datetime.time(8, 13), datetime.time(8, 30), 0.0, 17.0),
#  ('1452144783', datetime.time(8, 30), datetime.time(8, 43), datetime.time(9, 0), 0.0, 17.0),
#  ('1451597137', datetime.time(7, 30), datetime.time(7, 43), datetime.time(8, 0), 0.0, 17.0),
#  ('1454169199', datetime.time(7, 0), datetime.time(18, 43), datetime.time(19, 0), 0.0, 17.0),
#  ('1452144254', datetime.time(7, 30), datetime.time(7, 43), datetime.time(8, 0), 0.0, 17.0),
#  ('1452016963', datetime.time(8, 0), datetime.time(8, 13), datetime.time(8, 30), 0.0, 17.0),
#  ('1452146044', datetime.time(8, 0), datetime.time(8, 12), datetime.time(8, 30), 0.0, 18.0),
#  ('1442671713', datetime.time(8, 0), datetime.time(8, 12), datetime.time(8, 30), 0.0, 18.0),
#  ('1438238885', datetime.time(7, 30), datetime.time(7, 42), datetime.time(8, 0), 0.0, 18.0),
#  ('1442838061', datetime.time(8, 30), datetime.time(9, 42), datetime.time(10, 0), 0.0, 18.0),
#  ('1451557024', datetime.time(9, 0), datetime.time(10, 12), datetime.time(10, 30), 0.0, 18.0),
#  ('1452145763', datetime.time(8, 0), datetime.time(8, 12), datetime.time(8, 30), 0.0, 18.0),
#  ('1446469300', datetime.time(8, 0), datetime.time(9, 11), datetime.time(9, 30), 0.0, 19.0),
#  ('1452145088', datetime.time(8, 0), datetime.time(8, 11), datetime.time(8, 30), 0.0, 19.0),
#  ('1452017074', datetime.time(8, 0), datetime.time(8, 11), datetime.time(8, 30), 0.0, 19.0),
#  ('1451612618', datetime.time(7, 30), datetime.time(7, 41), datetime.time(8, 0), 0.0, 19.0),
#  ('1452145738', datetime.time(8, 0), datetime.time(8, 11), datetime.time(8, 30), 0.0, 19.0),
#  ('1451546520', datetime.time(11, 0), datetime.time(12, 10), datetime.time(12, 30), 0.0, 20.0),
#  ('1452144310', datetime.time(8, 0), datetime.time(9, 10), datetime.time(9, 30), 0.0, 20.0),
#  ('1451597125', datetime.time(7, 30), datetime.time(7, 40), datetime.time(8, 0), 0.0, 20.0),
#  ('1442838048', datetime.time(8, 30), datetime.time(9, 40), datetime.time(10, 0), 0.0, 20.0),
#  ('1451601130', datetime.time(8, 0), datetime.time(8, 10), datetime.time(8, 30), 0.0, 20.0),
#  ('1451601098', datetime.time(7, 30), datetime.time(7, 40), datetime.time(8, 0), 0.0, 20.0),
#  ('1449413225', datetime.time(8, 30), datetime.time(9, 40), datetime.time(10, 0), 0.0, 20.0),
#  ('1434979404', datetime.time(7, 30), datetime.time(7, 40), datetime.time(8, 0), 0.0, 20.0),
#  ('1454070146', datetime.time(8, 30), datetime.time(8, 40), datetime.time(9, 0), 0.0, 20.0),
#  ('1442671701', datetime.time(8, 0), datetime.time(8, 10), datetime.time(8, 30), 0.0, 20.0),
#  ('1451601116', datetime.time(8, 0), datetime.time(8, 9), datetime.time(8, 30), 0.0, 21.0),
#  ('1452145222', datetime.time(11, 0), datetime.time(12, 9), datetime.time(12, 30), 0.0, 21.0),
#  ('1452145076', None, datetime.time(8, 9), datetime.time(8, 30), 0.0, 21.0),
#  ('1454070122', None, datetime.time(8, 9), datetime.time(8, 30), 0.0, 21.0),
#  ('1434979428', datetime.time(7, 30), datetime.time(7, 38), datetime.time(8, 0), 0.0, 22.0),
#  ('1454070110', datetime.time(8, 0), datetime.time(8, 7), datetime.time(8, 30), 0.0, 23.0),
#  ('1448446466', datetime.time(0, 0), datetime.time(2, 37), datetime.time(3, 0), 0.0, 23.0),
#  ('1451596947', datetime.time(7, 30), datetime.time(7, 37), datetime.time(8, 0), 0.0, 23.0),
#  ('1451601104', datetime.time(8, 0), datetime.time(8, 7), datetime.time(8, 30), 0.0, 23.0),
#  ('1452145143', datetime.time(8, 30), datetime.time(8, 37), datetime.time(9, 0), 0.0, 23.0),
#  ('1452145830', datetime.time(7, 30), datetime.time(7, 37), datetime.time(8, 0), 0.0, 23.0),
#  ('1452144369', datetime.time(8, 30), datetime.time(8, 36), datetime.time(9, 0), 0.0, 24.0),
#  ('1451556068', datetime.time(7, 30), datetime.time(7, 36), datetime.time(8, 0), 0.0, 24.0),
#  ('1452145726', datetime.time(8, 0), datetime.time(8, 6), datetime.time(8, 30), 0.0, 24.0),
#  ('1451546750', datetime.time(7, 30), datetime.time(7, 36), datetime.time(8, 0), 0.0, 24.0),
#  ('1451544558', datetime.time(7, 30), datetime.time(7, 35), datetime.time(8, 0), 0.0, 25.0),
#  ('1443132305', datetime.time(11, 30), datetime.time(12, 35), datetime.time(13, 0), 0.0, 25.0),
#  ('1452144722', datetime.time(11, 30), datetime.time(12, 35), datetime.time(13, 0), 0.0, 25.0),
#  ('1451557140', datetime.time(11, 0), datetime.time(12, 5), datetime.time(12, 30), 0.0, 25.0),
#  ('1449548490', datetime.time(7, 0), datetime.time(18, 35), datetime.time(19, 0), 0.0, 25.0),
#  ('1442405430', datetime.time(7, 30), datetime.time(7, 34), datetime.time(8, 0), 0.0, 26.0),
#  ('1451556044', datetime.time(11, 0), datetime.time(12, 3), datetime.time(12, 30), 0.0, 27.0),
#  ('1452144710', datetime.time(11, 30), datetime.time(12, 32), datetime.time(13, 0), 0.0, 28.0),
#  ('1443132275', datetime.time(11, 30), datetime.time(12, 32), datetime.time(13, 0), 0.0, 28.0),
#  ('1452144643', datetime.time(11, 0), datetime.time(12, 1), datetime.time(12, 30), 0.0, 29.0),
#  ('1452144709', datetime.time(11, 30), datetime.time(12, 31), datetime.time(13, 0), 0.0, 29.0),
#  ('1451546051', datetime.time(9, 0), datetime.time(10, 0), datetime.time(10, 30), 0.0, 30.0),
#  ('1447152396', datetime.time(9, 0), datetime.time(10, 0), datetime.time(10, 30), 0.0, 30.0),
#  ('1438225702', datetime.time(11, 0), datetime.time(12, 0), datetime.time(12, 30), 0.0, 30.0),
#  ('1447832231', datetime.time(9, 0), datetime.time(10, 30), datetime.time(11, 0), 0.0, 30.0),
#  ('1451265220', datetime.time(9, 30), datetime.time(10, 30), datetime.time(11, 0), 0.0, 30.0),
#  ('1449135110', datetime.time(8, 30), datetime.time(9, 30), datetime.time(10, 0), 0.0, 30.0),
#  ('1451557000', datetime.time(9, 0), datetime.time(9, 59), datetime.time(10, 30), 0.0, 31.0),
#  ('1452144692', datetime.time(11, 30), datetime.time(12, 29), datetime.time(13, 0), 0.0, 31.0),
#  ('1452145064', datetime.time(11, 0), datetime.time(11, 57), datetime.time(12, 30), 0.0, 33.0),
#  ('1447152384', datetime.time(9, 0), datetime.time(9, 55), datetime.time(10, 30), 0.0, 35.0),
#  ('1447832243', datetime.time(9, 0), datetime.time(10, 25), datetime.time(11, 0), 0.0, 35.0),
#  ('1454093225', datetime.time(11, 30), datetime.time(12, 25), datetime.time(13, 0), 0.0, 35.0),
#  ('1438225696', datetime.time(11, 0), datetime.time(11, 55), datetime.time(12, 30), 0.0, 35.0),
#  ('1452144620', datetime.time(11, 0), datetime.time(11, 54), datetime.time(12, 30), 0.0, 36.0),
#  ('1451264630', datetime.time(16, 0), datetime.time(18, 24), datetime.time(19, 0), 0.0, 36.0),
#  ('1438225684', datetime.time(11, 0), datetime.time(11, 53), datetime.time(12, 30), 0.0, 37.0),
#  ('1452144503', datetime.time(8, 30), datetime.time(9, 23), datetime.time(10, 0), 0.0, 37.0),
#  ('1451556998', datetime.time(9, 0), datetime.time(9, 53), datetime.time(10, 30), 0.0, 37.0),
#  ('1442783990', datetime.time(8, 30), datetime.time(9, 23), datetime.time(10, 0), 0.0, 37.0),
#  ('1451557127', datetime.time(11, 0), datetime.time(11, 52), datetime.time(12, 30), 0.0, 38.0),
#  ('1451585755', datetime.time(10, 30), datetime.time(11, 22), datetime.time(12, 0), 0.0, 38.0),
#  ('1452144680', datetime.time(11, 30), datetime.time(12, 22), datetime.time(13, 0), 0.0, 38.0),
#  ('1452145210', datetime.time(9, 0), datetime.time(9, 51), datetime.time(10, 30), 0.0, 39.0),
#  ('1451546014', datetime.time(8, 0), datetime.time(8, 50), datetime.time(9, 30), 0.0, 40.0),
#  ('1451857949', datetime.time(11, 0), datetime.time(11, 50), datetime.time(12, 30), 0.0, 40.0),
#  ('1447832220', datetime.time(9, 0), datetime.time(10, 20), datetime.time(11, 0), 0.0, 40.0),
#  ('1454109324', datetime.time(9, 0), datetime.time(9, 50), datetime.time(10, 30), 0.0, 40.0),
#  ('1451546130', datetime.time(9, 0), datetime.time(9, 50), datetime.time(10, 30), 0.0, 40.0),
#  ('1454071758', datetime.time(11, 30), datetime.time(12, 20), datetime.time(13, 0), 0.0, 40.0),
#  ('1452145570', datetime.time(9, 0), datetime.time(9, 50), datetime.time(10, 30), 0.0, 40.0),
#  ('1452145659', datetime.time(8, 0), datetime.time(8, 50), datetime.time(9, 30), 0.0, 40.0),
#  ('1438225672', datetime.time(11, 0), datetime.time(11, 48), datetime.time(12, 30), 0.0, 42.0),
#  ('1454215215', datetime.time(8, 30), datetime.time(9, 18), datetime.time(10, 0), 0.0, 42.0),
#  ('1452017050', datetime.time(9, 30), datetime.time(10, 18), datetime.time(11, 0), 0.0, 42.0),
#  ('1454093559', datetime.time(8, 0), datetime.time(8, 17), datetime.time(9, 0), 0.0, 43.0),
#  ('1451597162', datetime.time(9, 0), datetime.time(9, 47), datetime.time(10, 30), 0.0, 43.0),
#  ('1452146226', datetime.time(11, 0), datetime.time(11, 46), datetime.time(12, 30), 0.0, 44.0),
#  ('1449253027', datetime.time(11, 30), datetime.time(12, 16), datetime.time(13, 0), 0.0, 44.0),
#  ('1452017049', datetime.time(9, 30), datetime.time(10, 15), datetime.time(11, 0), 0.0, 45.0),
#  ('1454115373', datetime.time(8, 0), datetime.time(8, 15), datetime.time(9, 0), 0.0, 45.0),
#  ('1442671634', datetime.time(11, 0), datetime.time(11, 45), datetime.time(12, 30), 0.0, 45.0),
#  ('1451556974', datetime.time(9, 0), datetime.time(9, 45), datetime.time(10, 30), 0.0, 45.0),
#  ('1438225660', datetime.time(11, 0), datetime.time(11, 45), datetime.time(12, 30), 0.0, 45.0),
#  ('1454168572', datetime.time(7, 0), datetime.time(18, 14), datetime.time(19, 0), 0.0, 46.0),
#  ('1451557103', datetime.time(11, 0), datetime.time(11, 44), datetime.time(12, 30), 0.0, 46.0),
#  ('1451557097', datetime.time(11, 0), datetime.time(11, 43), datetime.time(12, 30), 0.0, 47.0),
#  ('1452146202', datetime.time(11, 0), datetime.time(11, 43), datetime.time(12, 30), 0.0, 47.0),
#  ('1452017037', datetime.time(9, 30), datetime.time(10, 13), datetime.time(11, 0), 0.0, 47.0),
#  ('1454093274', datetime.time(11, 30), datetime.time(12, 12), datetime.time(13, 0), 0.0, 48.0),
#  ('1433689406', datetime.time(11, 30), datetime.time(12, 12), datetime.time(13, 0), 0.0, 48.0),
#  ('1452144850', datetime.time(8, 30), datetime.time(9, 12), datetime.time(10, 0), 0.0, 48.0),
#  ('1451597150', datetime.time(9, 0), datetime.time(9, 42), datetime.time(10, 30), 0.0, 48.0),
#  ('1434979430', datetime.time(7, 30), datetime.time(7, 42), datetime.time(8, 30), 0.0, 48.0),
#  ('1451597095', datetime.time(11, 30), datetime.time(12, 11), datetime.time(13, 0), 0.0, 49.0),
#  ('1452144886', datetime.time(8, 30), datetime.time(9, 11), datetime.time(10, 0), 0.0, 49.0),
#  ('1451571288', datetime.time(9, 0), datetime.time(9, 41), datetime.time(10, 30), 0.0, 49.0),
#  ('1448661419', datetime.time(11, 30), datetime.time(12, 10), datetime.time(13, 0), 0.0, 50.0),
#  ('1451546154', datetime.time(11, 0), datetime.time(11, 40), datetime.time(12, 30), 0.0, 50.0),
#  ('1452017025', datetime.time(9, 30), datetime.time(10, 10), datetime.time(11, 0), 0.0, 50.0),
#  ('1452019990', datetime.time(11, 0), datetime.time(11, 40), datetime.time(12, 30), 0.0, 50.0),
#  ('1454093250', datetime.time(11, 30), datetime.time(12, 10), datetime.time(13, 0), 0.0, 50.0),
#  ('1452144424', datetime.time(8, 30), datetime.time(9, 10), datetime.time(10, 0), 0.0, 50.0),
#  ('1438225659', datetime.time(11, 0), datetime.time(11, 40), datetime.time(12, 30), 0.0, 50.0),
#  ('1449416676', datetime.time(12, 0), datetime.time(12, 40), datetime.time(13, 30), 0.0, 50.0),
#  ('1454058419', datetime.time(8, 30), datetime.time(9, 10), datetime.time(10, 0), 0.0, 50.0),
#  ('1451557085', datetime.time(11, 0), datetime.time(11, 39), datetime.time(12, 30), 0.0, 51.0),
#  ('1452144412', datetime.time(8, 30), datetime.time(9, 8), datetime.time(10, 0), 0.0, 52.0),
#  ('1447199789', datetime.time(7, 0), datetime.time(18, 8), datetime.time(19, 0), 0.0, 52.0),
#  ('1451556962', datetime.time(9, 0), datetime.time(9, 38), datetime.time(10, 30), 0.0, 52.0),
#  ('1433689327', datetime.time(8, 0), datetime.time(8, 7), datetime.time(9, 0), 0.0, 53.0),
#  ('1452145805', datetime.time(8, 30), datetime.time(9, 7), datetime.time(10, 0), 0.0, 53.0),
#  ('1454170189', datetime.time(10, 0), datetime.time(10, 36), datetime.time(11, 30), 0.0, 54.0),
#  ('1452016987', datetime.time(9, 30), datetime.time(10, 6), datetime.time(11, 0), 0.0, 54.0),
#  ('1433689390', datetime.time(11, 30), datetime.time(12, 6), datetime.time(13, 0), 0.0, 54.0),
#  ('1451546038', datetime.time(11, 0), datetime.time(11, 35), datetime.time(12, 30), 0.0, 55.0),
#  ('1452144874', datetime.time(8, 30), datetime.time(9, 5), datetime.time(10, 0), 0.0, 55.0),
#  ('1447152359', datetime.time(9, 0), datetime.time(9, 35), datetime.time(10, 30), 0.0, 55.0),
#  ('1451546099', datetime.time(9, 0), datetime.time(9, 35), datetime.time(10, 30), 0.0, 55.0),
#  ('1452145260', datetime.time(9, 0), datetime.time(9, 35), datetime.time(10, 30), 0.0, 55.0),
#  ('1452144473', datetime.time(8, 30), datetime.time(9, 4), datetime.time(10, 0), 0.0, 56.0),
#  ('1452144953', datetime.time(11, 0), datetime.time(11, 34), datetime.time(12, 30), 0.0, 56.0),
#  ('1454168547', datetime.time(7, 0), datetime.time(18, 4), datetime.time(19, 0), 0.0, 56.0),
#  ('1451557061', datetime.time(11, 0), datetime.time(11, 33), datetime.time(12, 30), 0.0, 57.0),
#  ('1454170130', datetime.time(10, 0), datetime.time(10, 33), datetime.time(11, 30), 0.0, 57.0),
#  ('1454090420', datetime.time(10, 0), datetime.time(10, 33), datetime.time(11, 30), 0.0, 57.0),
#  ('1442838103', datetime.time(8, 30), datetime.time(9, 2), datetime.time(10, 0), 0.0, 58.0),
#  ('1454168535', datetime.time(7, 0), datetime.time(18, 2), datetime.time(19, 0), 0.0, 58.0),
#  ('1452146238', datetime.time(9, 0), datetime.time(9, 32), datetime.time(10, 30), 0.0, 58.0),
#  ('1433689388', datetime.time(11, 30), datetime.time(12, 2), datetime.time(13, 0), 0.0, 58.0),
#  ('1454170165', datetime.time(10, 0), datetime.time(10, 32), datetime.time(11, 30), 0.0, 58.0),
#  ('1452145386', datetime.time(8, 0), datetime.time(8, 31), datetime.time(9, 30), 0.0, 59.0),
#  ('1452144400', datetime.time(8, 30), datetime.time(9, 1), datetime.time(10, 0), 0.0, 59.0),
#  ('1452144436', datetime.time(9, 0), datetime.time(9, 31), datetime.time(10, 30), 0.0, 59.0),
#  ('1452144540', datetime.time(8, 30), datetime.time(9, 1), datetime.time(10, 0), 0.0, 59.0),
#  ('1452145258', datetime.time(9, 0), datetime.time(9, 31), datetime.time(10, 30), 0.0, 59.0),
#  ('1452145155', datetime.time(8, 30), datetime.time(8, 20), datetime.time(9, 0), 1.0, -20.0),
#  ('1449024427', datetime.time(23, 0), datetime.time(5, 45), datetime.time(6, 30), 1.0, -15.0),
#  ('1454093249', datetime.time(23, 30), datetime.time(12, 5), datetime.time(13, 0), 1.0, -5.0)]

# %% [markdown]
# ### violation after `to_hours_in_effect`

# %%
# %%sql
#
# With diff_time AS (
# SELECT
#         summons_number,
#         from_hours_in_effect,
#         violation_time,
#         to_hours_in_effect,
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '05:00:00'::time
#                     THEN  24- EXTRACT('hour' FROM to_hours_in_effect) + EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                     THEN (- EXTRACT('hour' FROM violation_time ) + EXTRACT('hour' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('hour' FROM to_hours_in_effect) - EXTRACT('hour' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (24- EXTRACT('hour' FROM violation_time )+EXTRACT('hour' FROM to_hours_in_effect) )
#             ELSE EXTRACT('hour' FROM to_hours_in_effect -  violation_time)
#             END AS hours,
#
#         CASE
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND to_hours_in_effect >= violation_time AND  violation_time >= from_hours_in_effect
#                  THEN  EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                  AND violation_time < '06:00:00'::time
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) + EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect > from_hours_in_effect
#                 AND violation_time NOT BETWEEN from_hours_in_effect AND to_hours_in_effect
#                 THEN  EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                     AND (violation_time > to_hours_in_effect AND violation_time < from_hours_in_effect)
#                    THEN (- EXTRACT('minute' FROM violation_time ) + EXTRACT('minute' FROM to_hours_in_effect) )
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND violation_time < to_hours_in_effect
#                     THEN   EXTRACT('minute' FROM to_hours_in_effect) - EXTRACT('minute' FROM  violation_time)
#             WHEN to_hours_in_effect < from_hours_in_effect
#                      AND (violation_time > to_hours_in_effect)
#                     THEN (-EXTRACT('minute' FROM violation_time )+EXTRACT('minute' FROM to_hours_in_effect) )
#             ELSE EXTRACT('minute' FROM to_hours_in_effect -  violation_time)
#             END AS minutes
#     FROM
#         (SELECT
#             summons_number,
#                 TO_TIMESTAMP(from_hours_in_effect, 'HH12MIPM')::time as from_hours_in_effect,
#                 TO_TIMESTAMP(to_hours_in_effect, 'HH12MIPM')::time as to_hours_in_effect,
#                 TO_TIMESTAMP(violation_time, 'HH12MIPM')::time as violation_time
#           FROM
#             parking_violation
#           WHERE NOT (from_hours_in_effect = '1200AM' AND to_hours_in_effect = '1159PM')
#         ) sub
# )
#
# SELECT summons_number,
#         from_hours_in_effect,
#         violation_time,
#         to_hours_in_effect,
#         hours AS violation_after_to_hours,
#         minutes
# FROM diff_time
# WHERE
# hours *60 + minutes <0
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 16 rows affected.
# [('4011361938', None, datetime.time(20, 34), datetime.time(10, 30), -10.0, -4.0),
#  ('4011361975', None, datetime.time(20, 48), datetime.time(10, 30), -10.0, -18.0),
#  ('4011362815', None, datetime.time(10, 52), datetime.time(10, 30), 0.0, -22.0),
#  ('4011362827', None, datetime.time(11, 5), datetime.time(10, 30), 0.0, -35.0),
#  ('4011362839', None, datetime.time(11, 8), datetime.time(10, 30), 0.0, -38.0),
#  ('4011363534', None, datetime.time(14, 24), datetime.time(10, 30), -3.0, -54.0),
#  ('4011363601', None, datetime.time(14, 33), datetime.time(10, 30), -4.0, -3.0),
#  ('4011363613', None, datetime.time(14, 34), datetime.time(10, 30), -4.0, -4.0),
#  ('4011363625', None, datetime.time(14, 35), datetime.time(10, 30), -4.0, -5.0),
#  ('4011363583', None, datetime.time(14, 29), datetime.time(10, 30), -3.0, -59.0),
#  ('4011363560', None, datetime.time(14, 28), datetime.time(10, 30), -3.0, -58.0),
#  ('1454169692', datetime.time(19, 0), datetime.time(15, 9), datetime.time(7, 0), -8.0, -9.0),
#  ('4011361940', None, datetime.time(20, 37), datetime.time(10, 30), -10.0, -7.0),
#  ('1446646427', datetime.time(0, 0), datetime.time(21, 35), datetime.time(12, 0), -9.0, -35.0),
#  ('1451849291', datetime.time(0, 1), datetime.time(12, 43), datetime.time(12, 0), 0.0, -43.0),
#  ('1447412710', datetime.time(23, 0), datetime.time(12, 40), datetime.time(6, 0), -6.0, -40.0)]
