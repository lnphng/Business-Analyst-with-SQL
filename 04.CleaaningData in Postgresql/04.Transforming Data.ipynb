# %% [markdown]
# ## Transforming Data
#
# - Transforming data and construct pivot tables.
# - Combining and spliting data like addresses into city, state, and zip codes using a multitude of powerful functions

# %%
cursor.execute("""SELECT table_name FROM information_schema.tables WHERE table_schema = 'public'""")
print('Table in Database:\n')
for table in cursor.fetchall():
       print(table)
# Out:
# Table in Database:
#
# ('film_permit',)
# ('parking_violation',)

# %%
# %%sql
# select COLUMN_NAME
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='parking_violation'
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 43 rows affected.
# [('summons_number',),
#  ('plate_id',),
#  ('registration_state',),
#  ('plate_type',),
#  ('issue_date',),
#  ('violation_code',),
#  ('vehicle_body_type',),
#  ('vehicle_make',),
#  ('issuing_agency',),
#  ('street_code1',),
#  ('street_code2',),
#  ('street_code3',),
#  ('vehicle_expiration_date',),
#  ('violation_location',),
#  ('violation_precinct',),
#  ('issuer_precint',),
#  ('issuer_code',),
#  ('issuer_command',),
#  ('issuer_squad',),
#  ('violation_time',),
#  ('time_first_observed',),
#  ('violation_county',),
#  ('violation_in_front_of_or_opposite',),
#  ('house_number',),
#  ('street_name',),
#  ('intersecting_street',),
#  ('date_first_observed',),
#  ('law_section',),
#  ('sub_division',),
#  ('violation_legal_code',),
#  ('days_parking_in_effect',),
#  ('from_hours_in_effect',),
#  ('to_hours_in_effect',),
#  ('vehicle_color',),
#  ('unregistred_vehicle',),
#  ('vehicle_year',),
#  ('meter_number',),
#  ('feet_from_curb',),
#  ('violation_post_code',),
#  ('violation_description',),
#  ('no_standing_or_stopping_violation',),
#  ('hydrant_violation',),
#  ('double_parking_violation',)]

# %%
# %%sql
# SELECT *
# FROM parking_violation
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('1447634159', 'HZR6973', 'NY', 'PAS', '05/03/2019', '20', None, 'DODGE', 'X', '0', '0', '0', '20200507', '122', '122', '835', '582', '0835', '0000', '1022PM', None, None, None, None, 'GNRA GREAT KILLS PAR', 'CEDAR PT BAY SIDE', '0', '408', 'D3', None, 'BBBBBBB', '0800PM', '0500AM', 'BLA', '0', 2014, '-', '0', None, None, None, None, None),
#  ('1447672290', 'HZN3898', 'NY', 'PAS', '07/13/2019', '14', 'SUBN', 'JEEP', 'X', '10010', '17310', '17330', '20200628', '0013', '13', '839', '111169', '0839', '0000', '0350AM', '0005A', 'NY', 'F', '280', 'FIRST AVENUE', None, '0', '408', 'D', None, 'BBBBBBB', '1000PM', '0700AM', 'GREY', '0', 2005, '-', '0', None, None, None, None, None),
#  ('1447680091', 'JDN5893', 'NY', 'PAS', '07/11/2019', '14', 'SUBN', 'BMW', 'X', '17270', '12110', '12210', '20201108', '0013', '13', '839', '111169', '0839', '0000', '0440AM', '0115A', 'NY', 'F', '545', 'E 14 ST', None, '20190711', '408', 'C', None, 'BBBBBBB', '1000PM', '0700AM', 'BLUE', '0', 2019, '-', '0', None, None, None, None, None),
#  ('1447680133', 'JDR8554', 'NY', 'PAS', '07/11/2019', '14', 'SDN', 'BMW', 'X', '12310', '17310', '10555', '20210208', '0013', '13', '839', '111169', '0839', '0000', '0412AM', None, 'NY', 'F', '283', 'AVE C', None, '0', '408', 'D', None, 'BBBBBBB', '1000PM', '0700AM', 'SILVE', '0', 2013, '-', '0', None, None, None, None, None),
#  ('1447680194', 'KWX4460', 'PA', 'PAS', '07/09/2019', '14', 'SUBN', 'TOYOT', 'X', '17270', '12110', '12210', '0', '0013', '13', '839', '111169', '0839', '0000', '0430AM', '0010A', 'NY', 'F', '521', 'E 14 STREET', None, '0', '408', 'C', None, 'BBBBBBB', '1000PM', '0700AM', 'BLUE', '0', 0, '-', '0', None, None, None, None, None),
#  ('1447315157', 'HWV8487', 'NY', 'PAS', '06/30/2019', '14', 'SUBN', 'NISSA', 'P', '83630', '90980', '53730', '20200201', '0060', '60', '60', '959840', '0060', '0000', '0430PM', None, 'K', 'O', '1005', 'SURF AVE', None, '0', '408', 'C', None, 'BBBBBBB', '1200AM', '1159PM', None, '0', 0, '-', '0', None, None, None, None, None),
#  ('1447316198', 'JEB6550', 'NY', 'PAS', '07/02/2019', '98', 'SUBN', 'KIA', 'P', '36780', '14080', '14130', '20201022', '0063', '63', '63', '963432', '0063', '0000', '0734PM', None, 'K', 'F', '1162', 'E 43 ST', None, '0', '408', 'J3', None, 'BBBBBBB', '1200AM', '1159PM', None, '0', 0, '-', '0', None, None, None, None, None),
#  ('1447320359', 'KMJ1971', 'PA', 'PAS', '07/02/2019', '98', 'SUBN', 'CHRYS', 'P', '54050', '14080', '14030', '20190930', '0063', '63', '63', '957004', '0063', '0000', '0948PM', None, 'K', 'F', '4539', 'KINGS HWY', None, '0', '408', 'F2', None, 'BBBBBBB', '1200AM', '1159PM', 'RED', '0', 2006, '-', '0', None, None, None, None, None),
#  ('1447336719', 'GBD9462', 'NY', 'PAS', '06/29/2019', '19', 'SUBN', 'HONDA', 'P', '22680', '75910', '22580', '20200806', '0060', '60', '60', '961254', '0060', '0000', '0900PM', None, 'K', 'F', '1117', 'BRIGHTON BEACH AVENU', None, '0', '408', 'F1', None, 'BBBBBBB', '1200AM', '1159PM', 'GY', '0', 2016, '-', '0', None, None, None, None, None),
#  ('1422683254', 'IBY3257', 'PA', 'PAS', '07/02/2019', '21', None, 'DODGE', 'P', '43520', '26550', '76950', '20210418', '0041', '41', '41', '963629', '0041', '0000', '0830AM', '0830A', None, 'F', '970', 'KELLY ST', None, '20190702', '408', 'F1', None, 'BYBBYBB', None, '1030AM', None, '0', 0, '-', '0', None, None, None, None, None)]

# %% [markdown]
# ### Combining columns
# #### Tallying corner parking violations
#
# - The `parking_violation` table has two columns (`street_name` and `intersecting_street`) with New York City streets.
# - When the values for both columns are not `NULL`, this indicates that the violation occurred on a corner where two streets intersect.
# - **Tasks:**
#     - identify street `corner`s that tend to be the location of frequent parking violations and
#     - identify the `total number` of violations at each corner.

# %%
# %%sql
# SELECT
# street_name,
# intersecting_street, corner
# FROM
#     (SELECT
#     street_name,
#     intersecting_street,
#
#             street_name || ' & ' || intersecting_street AS corner
#     FROM
#             parking_violation) sub
# WHERE corner is NOT NULL;
#
# SELECT street_name,
# intersecting_street
# FROM parking_violation
# WHERE street_name is NULL OR intersecting_street IS NULL;
#
# SELECT count(street_name)
# FROM parking_violation
# WHERE NOT (street_name is NULL OR intersecting_street IS NULL);
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 568 rows affected.
# 4432 rows affected.
# 1 rows affected.
# [(568,)]

# %%
# %%sql
# SELECT
#     corner,
#     count(*) as total_number
# FROM (
#     SELECT
#         street_name || ' & ' || intersecting_street AS corner
#     FROM
#         parking_violation
#     ) sub
# WHERE corner IS NOT NULL
# GROUP BY corner
# HAVING count(*) > 2
# ORDER BY total_number DESC
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 14 rows affected.
# [('RIVERBANK STATE PARK & LOWER LEVEL', 10),
#  ('FR CAPODANNO BLVD & SAND LN', 7),
#  ('JACOB RIIS PARK & EAST PARKING LOT', 6),
#  ('ROCKAWAY BEACH & SHORE FRONT PKWY', 5),
#  ('BRUCKNER BLVD & WILKINSON AVE', 5),
#  ('CROTONA & CLAREMONT PKWY', 5),
#  ('CLAREMONT PKWY & CROTONA AVE', 4),
#  ('SURF AVE & W 15TH ST', 4),
#  ('N/S JEROME AVE & ANDERSON AVE', 4),
#  ('RIVERBANK STATE PARK & UPPER LEVEL', 3),
#  ('EB E 163RD ST @ SIMP & SON ST', 3),
#  ('CEDAR GROVE PKG LOT & MILLER FIELD', 3),
#  ('BEACH 87 ST & ROCKAWAY FWY', 3),
#  ('JACOB RIIS PARK & EAST  PARKING LOT', 3)]

# %% [markdown]
# #### TIMESTAMP with concatenation
#
# - Identifying overnight violations through the creation of the `violation_datetime` column populated with `TIMESTAMP` values.
# - Concatenating `issue_date` and `violation_time` and converting the resulting strings to `TIMESTAMP` values.

# %%
# %%sql
#
# SELECT
#     issue_date,
#     violation_time,
# -- Concatenate issue_date and violation_time columns
#     CONCAT(issue_date, ' ', violation_time) AS violation_datetime
# FROM
#   parking_violation
# LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 20 rows affected.
# [('05/03/2019', '1022PM', '05/03/2019 1022PM'),
#  ('07/13/2019', '0350AM', '07/13/2019 0350AM'),
#  ('07/11/2019', '0440AM', '07/11/2019 0440AM'),
#  ('07/11/2019', '0412AM', '07/11/2019 0412AM'),
#  ('07/09/2019', '0430AM', '07/09/2019 0430AM'),
#  ('06/30/2019', '0430PM', '06/30/2019 0430PM'),
#  ('07/02/2019', '0734PM', '07/02/2019 0734PM'),
#  ('07/02/2019', '0948PM', '07/02/2019 0948PM'),
#  ('06/29/2019', '0900PM', '06/29/2019 0900PM'),
#  ('07/02/2019', '0830AM', '07/02/2019 0830AM'),
#  ('07/08/2019', '0850AM', '07/08/2019 0850AM'),
#  ('06/27/2019', '0311AM', '06/27/2019 0311AM'),
#  ('06/29/2019', '0700PM', '06/29/2019 0700PM'),
#  ('06/28/2019', '1201PM', '06/28/2019 1201PM'),
#  ('06/19/2019', '0135AM', '06/19/2019 0135AM'),
#  ('06/14/2019', '0833AM', '06/14/2019 0833AM'),
#  ('06/01/2019', '0834PM', '06/01/2019 0834PM'),
#  ('06/16/2019', '0525PM', '06/16/2019 0525PM'),
#  ('07/04/2019', '1025PM', '07/04/2019 1025PM'),
#  ('06/14/2019', '0325PM', '06/14/2019 0325PM')]

# %%
# %%sql
# SELECT
#     issue_date,
#     violation_time,
#   -- Convert violation_time to TIMESTAMP
#   TO_TIMESTAMP(violation_datetime, 'MM/DD/YYYY HH12MIPM') AS violation_datetime
# FROM (
#   SELECT
#     issue_date,
#     violation_time,
#     CONCAT(issue_date, ' ', violation_time) AS violation_datetime
#   FROM
#     parking_violation
# ) sub
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('05/03/2019', '1022PM', datetime.datetime(2019, 5, 3, 22, 22, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/13/2019', '0350AM', datetime.datetime(2019, 7, 13, 3, 50, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/11/2019', '0440AM', datetime.datetime(2019, 7, 11, 4, 40, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/11/2019', '0412AM', datetime.datetime(2019, 7, 11, 4, 12, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/09/2019', '0430AM', datetime.datetime(2019, 7, 9, 4, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('06/30/2019', '0430PM', datetime.datetime(2019, 6, 30, 16, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/02/2019', '0734PM', datetime.datetime(2019, 7, 2, 19, 34, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/02/2019', '0948PM', datetime.datetime(2019, 7, 2, 21, 48, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('06/29/2019', '0900PM', datetime.datetime(2019, 6, 29, 21, 0, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None))),
#  ('07/02/2019', '0830AM', datetime.datetime(2019, 7, 2, 8, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None)))]

# %% [markdown]
# ### Spliting column data
# #### Extracting time units

# %%
# %%sql
# SELECT
#     violation_time,
#     SUBSTRING(violation_time FROM 1 FOR 2) AS hour,
#     -- Define minute column
#     SUBSTRING(violation_time FROM 3 FOR 2) AS minute
# FROM
#   parking_violation
#     LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('1022PM', '10', '22'),
#  ('0350AM', '03', '50'),
#  ('0440AM', '04', '40'),
#  ('0412AM', '04', '12'),
#  ('0430AM', '04', '30'),
#  ('0430PM', '04', '30'),
#  ('0734PM', '07', '34'),
#  ('0948PM', '09', '48'),
#  ('0900PM', '09', '00'),
#  ('0830AM', '08', '30')]

# %% [markdown]
# #### Extracting house numbers from a string

# %% [markdown]
# `house_number` = `cross street`_ `house_number`
# > new_house_number = `house_number`

# %%
# %%sql
# SELECT
#         house_number,
#         SUBSTRING(
#             house_number
#             FROM STRPOS(house_number, '-') + 1
#             FOR LENGTH(house_number) - STRPOS(house_number, '-')
#             ) AS new_house_number,
#         street_name
# FROM  parking_violation
# WHERE house_number LIKE '%-%'
#     LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('32-11', '11', '98 ST'),
#  ('145-43', '43', '157 ST'),
#  ('107-18', '18', 'WALTHAM ST'),
#  ('16-12', '12', 'ELIZABETH ST'),
#  ('90-38', '38', '179 PL'),
#  ('145-59', '59', '3RD AVE'),
#  ('116-28', '28', 'QUEENS BLVD'),
#  ('145-32', '32', '3RD AVE'),
#  ('145-52', '52', '3 AVE'),
#  ('129-10', '10', 'HILLSIDE AVE')]

# %% [markdown]
# #### Splitting data with delimiters

# %%
# %%sql
# SELECT
#   -- Split house_number using '-' as the delimiter
#   SPLIT_PART(house_number, '-', 2) AS new_house_number,
# violation_county
# FROM
#   parking_violation
# WHERE
#   violation_county = 'Q'
#     LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('11', 'Q'),
#  ('43', 'Q'),
#  ('18', 'Q'),
#  ('38', 'Q'),
#  ('59', 'Q'),
#  (None, 'Q'),
#  (None, 'Q'),
#  (None, 'Q'),
#  ('28', 'Q'),
#  ('32', 'Q')]

# %%
# %%sql
#
# SELECT
#   -- Label daily parking restrictions for locations by day
#   ROW_NUMBER() OVER(
#     PARTITION BY
#         house_number,
#     street_name, violation_county
#     ORDER BY
#         1, 7
#   ) AS day_number,
#   *
# FROM (
#   SELECT
#     house_number,
#     street_name,
#     violation_county,
#     REGEXP_SPLIT_TO_TABLE(days_parking_in_effect, '') AS daily_parking_restriction
#   FROM
#     parking_violation
# ) sub
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [(1, '0348', 'LINDEN RD', 'K', 'B'),
#  (2, '0348', 'LINDEN RD', 'K', 'B'),
#  (3, '0348', 'LINDEN RD', 'K', 'B'),
#  (4, '0348', 'LINDEN RD', 'K', 'B'),
#  (5, '0348', 'LINDEN RD', 'K', 'B'),
#  (6, '0348', 'LINDEN RD', 'K', 'B'),
#  (7, '0348', 'LINDEN RD', 'K', 'B'),
#  (1, '05', 'ALICE COURT', 'K', 'B'),
#  (2, '05', 'ALICE COURT', 'K', 'B'),
#  (3, '05', 'ALICE COURT', 'K', 'B')]

# %% [markdown]
# ### Creating pivot table
# #### Selecting data for a pivot table
#
# `issuing_agency`: agencies responsible for different types of parking violations including `Police Department` (`P`), `Department of Sanitation` (`S`), `Parks Department` (`K`), and `Department of Transportation` (`V`)

# %%
# %%sql
# SELECT
#     -- Include the violation code in results
#     violation_code,
#     -- Include the issuing agency in results
#     issuing_agency,
#     -- Total violation code and issuing agency pairs
#     COUNT(issuing_agency)
# FROM
#     parking_violation
# WHERE
#     -- Restrict the results to the agencies of interest
#     issuing_agency IN ('P', 'S', 'K', 'V')
# GROUP BY
#     -- Define GROUP BY columns to ensure correct pair count
#     violation_code, issuing_agency
# ORDER BY
#     violation_code, issuing_agency
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('10', 'P', 3),
#  ('11', 'P', 1),
#  ('13', 'K', 1),
#  ('14', 'K', 4),
#  ('14', 'P', 485),
#  ('14', 'S', 4),
#  ('16', 'P', 10),
#  ('17', 'P', 69),
#  ('17', 'S', 8),
#  ('18', 'P', 9)]

# %% [markdown]
# #### Using FILTER to create a pivot table

# %%
# %%sql
# SELECT
#     violation_code,
#     -- Define the "Police" column
#     count(violation_code) FILTER (WHERE issuing_agency = 'P') AS "Police",
#     -- Define the "Sanitation" column
#     count(violation_code) FILTER (WHERE issuing_agency = 'S') AS "Sanitation",
#     -- Define the "Parks" column
#     count(violation_code) FILTER (WHERE issuing_agency = 'K') AS "Parks",
#     -- Define the "Transportation" column
#     count(violation_code) FILTER (WHERE issuing_agency = 'V') AS "Transportation"
# FROM parking_violation
# GROUP BY violation_code
# ORDER BY violation_code
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 59 rows affected.
# [('10', 3, 0, 0, 0),
#  ('11', 1, 0, 0, 0),
#  ('13', 0, 0, 1, 0),
#  ('14', 485, 4, 4, 0),
#  ('16', 10, 0, 0, 0),
#  ('17', 69, 8, 0, 0),
#  ('18', 9, 0, 0, 0),
#  ('19', 203, 4, 1, 0),
#  ('20', 387, 8, 17, 0),
#  ('21', 42, 271, 0, 0),
#  ('24', 48, 0, 11, 0),
#  ('27', 51, 0, 1, 0),
#  ('31', 4, 0, 0, 0),
#  ('34', 1, 0, 0, 0),
#  ('37', 3, 0, 0, 0),
#  ('38', 10, 0, 0, 0),
#  ('39', 1, 0, 2, 0),
#  ('4', 2, 0, 0, 0),
#  ('40', 548, 9, 1, 0),
#  ('41', 39, 0, 0, 0),
#  ('42', 1, 0, 0, 0),
#  ('43', 10, 0, 0, 0),
#  ('45', 26, 1, 10, 0),
#  ('46', 516, 2, 1, 0),
#  ('48', 158, 0, 0, 0),
#  ('5', 0, 0, 0, 15),
#  ('50', 97, 0, 0, 0),
#  ('51', 140, 0, 1, 0),
#  ('52', 4, 1, 0, 0),
#  ('53', 29, 0, 1, 0),
#  ('56', 6, 0, 0, 0),
#  ('6', 3, 0, 0, 0),
#  ('60', 12, 0, 0, 0),
#  ('61', 13, 1, 0, 0),
#  ('62', 23, 0, 2, 0),
#  ('63', 44, 0, 1, 0),
#  ('64', 1, 0, 0, 0),
#  ('66', 4, 1, 0, 0),
#  ('67', 88, 2, 1, 0),
#  ('68', 12, 15, 1, 0),
#  ('70', 45, 1, 0, 0),
#  ('71', 70, 0, 1, 0),
#  ('72', 2, 0, 0, 0),
#  ('74', 38, 0, 0, 0),
#  ('75', 4, 0, 0, 0),
#  ('77', 1, 0, 0, 0),
#  ('78', 12, 0, 0, 0),
#  ('80', 2, 0, 0, 0),
#  ('83', 14, 0, 0, 0),
#  ('85', 3, 0, 0, 0),
#  ('87', 1, 0, 0, 0),
#  ('9', 4, 1, 1, 0),
#  ('90', 2, 0, 0, 0),
#  ('91', 1, 0, 0, 0),
#  ('92', 1, 0, 0, 0),
#  ('96', 5, 0, 0, 0),
#  ('97', 1, 0, 0, 0),
#  ('98', 734, 1, 1, 0),
#  ('99', 25, 0, 0, 0)]

# %% [markdown]
# ### Aggregating film categories

# %%
# %%sql
# SELECT column_name
# FROM INFORMATION_SCHEMA.COLUMNS
# WHERE TABLE_NAME='film_permit'
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('event_id',),
#  ('event_type',),
#  ('start_date_time',),
#  ('end_date_time',),
#  ('entered_on',),
#  ('event_agency',),
#  ('parking_held',),
#  ('borough',),
#  ('community_board',),
#  ('police_precinct',)]

# %%
# %%sql
# SELECT
# event_id
# ,event_type
# ,start_date_time
# ,end_date_time
# ,entered_on
# ,event_agency
# --,parking_held
# ,borough
# ,community_board
# ,police_precinct
#
# FROM film_permit
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# 10 rows affected.
# [('446040', 'Shooting Permit', '10/19/2018 02:00:00 PM', '10/20/2018 04:00:00 AM', '10/16/2018 11:57:27 AM', "Mayor's Office of Film, Theatre & Broadcasting", 'Manhattan', '2', '1'),
#  ('446168', 'Shooting Permit', '10/19/2018 02:00:00 PM', '10/20/2018 02:00:00 AM', '10/16/2018 07:03:56 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Manhattan', '12, 8', '34, 50'),
#  ('186438', 'Shooting Permit', '10/30/2014 07:00:00 AM', '10/31/2014 02:00:00 AM', '10/27/2014 12:14:15 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Queens', '2, 5', '104, 108'),
#  ('445255', 'Shooting Permit', '10/20/2018 07:00:00 AM', '10/20/2018 06:00:00 PM', '10/09/2018 09:34:58 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Brooklyn', '2', '84'),
#  ('128794', 'Theater Load in and Load Outs', '11/16/2013 12:01:00 AM', '11/17/2013 06:00:00 AM', '11/07/2013 03:48:28 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Manhattan', '4, 5', '14'),
#  ('43547', 'Shooting Permit', '01/10/2012 07:00:00 AM', '01/10/2012 07:00:00 PM', '01/04/2012 12:25:37 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Brooklyn', '1, 2', '108, 94'),
#  ('66846', 'Shooting Permit', '07/27/2012 07:00:00 AM', '07/27/2012 07:00:00 PM', '07/23/2012 07:26:03 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Brooklyn', '6', '78'),
#  ('104342', 'Shooting Permit', '06/21/2013 12:00:00 AM', '06/21/2013 09:00:00 AM', '05/27/2013 06:22:39 AM', "Mayor's Office of Film, Theatre & Broadcasting", 'Manhattan', '5', '14'),
#  ('244863', 'Shooting Permit', '09/16/2015 07:00:00 AM', '09/16/2015 09:00:00 PM', '09/10/2015 10:26:27 PM', "Mayor's Office of Film, Theatre & Broadcasting", 'Bronx', '11', '49'),
#  ('446379', 'Shooting Permit', '10/20/2018 06:00:00 AM', '10/20/2018 10:00:00 PM', '10/18/2018 11:01:48 AM', "Mayor's Office of Film, Theatre & Broadcasting", 'Manhattan', '2', '6')]

# %%
# %%sql
# CREATE OR REPLACE TEMP VIEW cb_categories AS
# SELECT
#
#     REGEXP_SPLIT_TO_TABLE(community_board, ', ') AS community_board, category
# FROM film_permit
# WHERE category IN ('Film', 'Television', 'Documentary')
# AND community_board !='N/A';
#
#
# SELECT
#     community_board::INT,
#     -- Define pivot table columns
#     COUNT(category) FILTER(where category = 'Film') AS "Film",
#     COUNT(category) FILTER(where category = 'Television') AS "Television",
#     COUNT(category) FILTER(where category = 'Documentary') AS "Documentary"
# FROM cb_categories
#
# GROUP BY community_board
# ORDER BY community_board;
# Out:
#  * postgresql://postgres:***@localhost:5432/NYC_Open_Data
# Done.
# 28 rows affected.
# [(0, 0, 1, 0),
#  (1, 166, 899, 5),
#  (2, 157, 656, 4),
#  (3, 90, 152, 3),
#  (4, 84, 281, 3),
#  (5, 131, 505, 5),
#  (6, 93, 188, 2),
#  (7, 76, 110, 0),
#  (8, 55, 103, 2),
#  (9, 64, 110, 1),
#  (10, 24, 50, 1),
#  (11, 34, 57, 1),
#  (12, 29, 48, 0),
#  (13, 9, 8, 1),
#  (14, 33, 35, 0),
#  (15, 11, 2, 0),
#  (16, 2, 4, 0),
#  (17, 5, 0, 0),
#  (18, 5, 1, 0),
#  (26, 0, 1, 0),
#  (27, 0, 1, 0),
#  (28, 0, 1, 0),
#  (55, 17, 15, 0),
#  (64, 27, 51, 1),
#  (80, 0, 1, 0),
#  (81, 0, 2, 0),
#  (82, 2, 10, 0),
#  (95, 0, 3, 0)]
